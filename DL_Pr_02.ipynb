# %%
# Fashion MNIST Classification using Deep Neural Network

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import fashion_mnist
from sklearn.metrics import classification_report

# %%
# Load Dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Normalize Data
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Class Labels
class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

# %%
# Build Deep Neural Network Model
model = Sequential()

# %%
# Flatten 28x28 image into 1D vector
model.add(Flatten(input_shape=(28, 28)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Hidden Layers
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))

# %%
# Output Layer
model.add(Dense(10, activation='softmax'))

# %%
# Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train Model
model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8159 - loss: 0.5150 - val_accuracy: 0.8583 - val_loss: 0.4079
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8586 - loss: 0.3819 - val_accuracy: 0.8427 - val_loss: 0.4161
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8748 - loss: 0.3402 - val_accuracy: 0.8701 - val_loss: 0.3601
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8816 - loss: 0.3182 - val_accuracy: 0.8707 - val_loss: 0.3572
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8896 - loss: 0.2973 - val_accuracy: 0.8738 - val_loss: 0.3456
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8946 - loss: 0.2836 - val_accuracy: 0.8783 - val_loss: 0.3413
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8984 - loss: 0.2724 - val_accuracy: 0.8828 - val_loss: 0.3276
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9013 - loss: 0.2593 - val_accuracy: 0.8793 - val_loss: 0.3517
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9073 - loss: 0.2484 - val_accuracy: 0.8860 - val_loss: 0.3248
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9108 - loss: 0.2398 - val_accuracy: 0.8870 - val_loss: 0.3226

# %%
# Evaluate Model
loss, accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8792 - loss: 0.3477
#
# Test Accuracy: 0.8791999816894531

# %%
# Predictions
predictions = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Display Some Predictions
print("\nSample Predictions:\n")

for i in range(10):
    predicted_label = np.argmax(predictions[i])

    print("Image", i + 1)
    print("Actual Label    :", class_names[y_test[i]])
    print("Predicted Label :", class_names[predicted_label])
    print()
# Out:
# Sample Predictions:
#
# Image 1
# Actual Label    : Ankle boot
# Predicted Label : Ankle boot
#
# Image 2
# Actual Label    : Pullover
# Predicted Label : Pullover
#
# Image 3
# Actual Label    : Trouser
# Predicted Label : Trouser
#
# Image 4
# Actual Label    : Trouser
# Predicted Label : Trouser
#
# Image 5
# Actual Label    : Shirt
# Predicted Label : Shirt
#
# Image 6
# Actual Label    : Trouser
# Predicted Label : Trouser
#
# Image 7
# Actual Label    : Coat
# Predicted Label : Coat
#
# Image 8
# Actual Label    : Shirt
# Predicted Label : Shirt
#
# Image 9
# Actual Label    : Sandal
# Predicted Label : Sandal
#
# Image 10
# Actual Label    : Sneaker
# Predicted Label : Sneaker
